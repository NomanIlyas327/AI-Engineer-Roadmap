# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

# %%
# Cell 2: File Handling & Data Generation (NumPy + Pandas)
# Task: NumPy ka istemal karke synthetic dataset banayein aur usko CSV file mein save/read karein.

# Columns to create (200 rows):

# Satisfaction_Level (float, e.g., 0.1 to 1.0)

# Monthly_Hours (integer, e.g., 90 to 300)

# Projects_Completed (integer, e.g., 1 to 10)

# Department (categorical text: 'Sales', 'IT', 'HR', 'Marketing')

# Performance_Score (formula/random continuous numbers for Regression)

# Will_Leave (binary 0/1 based on low satisfaction & high hours for Classification)

# File Operations:

# Dataset ko to_csv('employee_pipeline_data.csv') se save karein.

# Phir read_csv() se use load karke check karein (.head()).
